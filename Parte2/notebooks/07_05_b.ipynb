# %% [markdown]
# # Implementing a Generative Model

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (5.12.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (1.21.0)
# Requirement already satisfied: numpy>=1.17 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from transformers) (4.68.3)
# Requirement already satisfied: click>=8.4.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: colorama in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
# !pip install ipywidgets --upgrade
# Out:
# Requirement already satisfied: ipywidgets in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipywidgets) (9.14.1)
# Requirement already satisfied: traitlets>=4.3.1 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipywidgets) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
# !pip install torch torchvision torchaudio
# Out:
# ^C

# %%
import warnings
from transformers import GPT2LMHeadModel, GPT2Tokenizer

warnings.filterwarnings("ignore", category=FutureWarning)

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

tokenizer.pad_token_id = tokenizer.eos_token_id

input_text = 'In the IA fileds'
input_ids = tokenizer.encode(input_text, return_tensors='pt')

attention_mask = input_ids.ne(tokenizer.pad_token_id).long()

output = model.generate(
    input_ids,
    attention_mask=attention_mask,
    max_length = 100,
    no_repeat_ngram_size=2,
    num_return_sequences=1,
    pad_token_id = tokenizer.eos_token_id
)

generated_text = tokenizer.decode(output[0], skip_spetial_tokens=True)
print(generated_text)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# g:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\rtang\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# In the IA fileds, the first two letters of the name are the same as the last two, and the second letter is the letter that is used to indicate the date of birth.
#
# The first letter of each name is a letter, which is usually a single letter. The second and third letters are letters, usually two or three letters long. In the case of a name that has two letter letters in it, it is called a "double letter."
# . . .
#  (

# %%
import sys
print(sys.version)
# Out:
# 3.14.6 (main, Jun 11 2026, 04:05:02) [MSC v.1944 64 bit (AMD64)]
