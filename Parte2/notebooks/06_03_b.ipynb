# %% [markdown]
# ## Introduction to NLP

# %%
# !pip install nltk
import nltk
# Out:
# Requirement already satisfied: nltk in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: click in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from nltk) (4.68.3)
# Requirement already satisfied: colorama in G:\Meu Drive\Cursos\Python\MachineLearning\.venv\Lib\site-packages (from click->nltk) (0.4.6)

# %%
text = "On Wednesday, the Association for Computing Machinery, the world’s largest society of computing professionals, announced that Hinton, LeCun and Bengio had won this year’s Turing Award for their work on neural networks. The Turing Award, which was introduced in 1966, is often called the Nobel Prize of computing, and it includes a $1 million prize, which the three scientists will share."

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rtang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#from nltk.tokenize import sent_tokenize
#sent_tk = sent_tokenize(text)
#print("Sentence tokenizing the text: \n")
#print(sent_tk)
from nltk.tokenize import PunktSentenceTokenizer
PST = PunktSentenceTokenizer()
sent_tk = PST.tokenize(text)
print("Sentence tokenizing the text:\n")
print( sent_tk)
# Out:
# Sentence tokenizing the text:
#
# ['On Wednesday, the Association for Computing Machinery, the world’s largest society of computing professionals, announced that Hinton, LeCun and Bengio had won this year’s Turing Award for their work on neural networks.', 'The Turing Award, which was introduced in 1966, is often called the Nobel Prize of computing, and it includes a $1 million prize, which the three scientists will share.']

# %%
#from nltk.tokenize import word_tokenize
#word_tk = word_tokenize(text)
#print("Word tokenizing the text: \n")
#print(word_tk)
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
word_tk = tokenizer.tokenize(text)
print("Word tokenizing the text:\n")
print(word_tk)
# Out:
# Word tokenizing the text:
#
# ['On', 'Wednesday', ',', 'the', 'Association', 'for', 'Computing', 'Machinery', ',', 'the', 'world’s', 'largest', 'society', 'of', 'computing', 'professionals', ',', 'announced', 'that', 'Hinton', ',', 'LeCun', 'and', 'Bengio', 'had', 'won', 'this', 'year’s', 'Turing', 'Award', 'for', 'their', 'work', 'on', 'neural', 'networks.', 'The', 'Turing', 'Award', ',', 'which', 'was', 'introduced', 'in', '1966', ',', 'is', 'often', 'called', 'the', 'Nobel', 'Prize', 'of', 'computing', ',', 'and', 'it', 'includes', 'a', '$', '1', 'million', 'prize', ',', 'which', 'the', 'three', 'scientists', 'will', 'share', '.']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rtang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

sw = set(stopwords.words("english"))
print("Stop words in English language are: \n")
print(sw)
# Out:
# Stop words in English language are:
#
# {"mightn't", "i'm", 'should', 'how', 'these', "wasn't", 'if', 'him', 'needn', 'that', 'yourselves', 'above', 'll', 'can', 'further', 'few', 'both', 'down', 'in', "isn't", 'theirs', 'isn', 'had', "it'd", "it's", "i'd", "hasn't", 'into', "wouldn't", "you've", "he's", 'during', 'between', "mustn't", "we've", 'why', 'your', "you'd", "should've", 'have', "he'd", 'doesn', 'on', 'when', 'won', 'some', "couldn't", 'very', 'where', 's', 'm', 'wasn', 'yours', 'through', 'each', 'for', 'himself', 'only', "shouldn't", 'will', 't', "they'll", "we're", 'did', 'more', 'ourselves', 'here', 'shouldn', 'we', 'you', 'am', 'now', 'of', "we'd", 'his', 'such', 'there', 'y', 'over', 'once', "you'll", 'she', 'is', 'the', 'been', 'was', 'my', "don't", 'hasn', "haven't", 'hadn', 'under', 'whom', 'by', 'own', "she'd", 'those', 'no', 'being', 'and', 'or', 'so', 'its', 'were', 'aren', "doesn't", 'd', 'against', "won't", "they're", 'wouldn', 'hers', 'mustn', 'same', 'weren', 'didn', 'because', 'having', 've', "we'll", "they've", 'this', 'but', 'are', 'than', 'with', 'nor', 'from', 'what', 'not', 'they', 'until', 'couldn', 'a', 'myself', 'mightn', 'as', 'he', 'after', 'then', "aren't", "didn't", "i've", "she'll", 'i', 'it', 'ma', 'her', 'again', 'has', 'haven', 'o', 'be', 'to', 'itself', 'herself', 'shan', 'just', 'do', 'all', 'don', 'at', 'themselves', 'ours', 'other', 'doing', "i'll", 'an', 'who', 'does', 'about', "it'll", 'which', 'before', 'their', "that'll", 'while', "he'll", "you're", 'out', 'any', "needn't", 'me', 'most', "she's", 'too', 'up', 'yourself', 'below', "hadn't", "shan't", "weren't", 'ain', 'our', 're', 'off', "they'd", 'them'}

# %%
filtered_words = [w for w in word_tk if not w in sw]

print("The text after removing stop words \n")
print(filtered_words)
# Out:
# The text after removing stop words
#
# ['On', 'Wednesday', ',', 'Association', 'Computing', 'Machinery', ',', 'world’s', 'largest', 'society', 'computing', 'professionals', ',', 'announced', 'Hinton', ',', 'LeCun', 'Bengio', 'year’s', 'Turing', 'Award', 'work', 'neural', 'networks.', 'The', 'Turing', 'Award', ',', 'introduced', '1966', ',', 'often', 'called', 'Nobel', 'Prize', 'computing', ',', 'includes', '$', '1', 'million', 'prize', ',', 'three', 'scientists', 'share', '.']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

port_stem = PorterStemmer()

# %%
stemmed_words = []

for w in filtered_words:
    stemmed_words.append(port_stem.stem(w))
    
print("Filtered Sentence: \n", filtered_words, "\n")
print("Stemmed Sentence: \n", stemmed_words)
# Out:
# Filtered Sentence:
#  ['On', 'Wednesday', ',', 'Association', 'Computing', 'Machinery', ',', 'world’s', 'largest', 'society', 'computing', 'professionals', ',', 'announced', 'Hinton', ',', 'LeCun', 'Bengio', 'year’s', 'Turing', 'Award', 'work', 'neural', 'networks.', 'The', 'Turing', 'Award', ',', 'introduced', '1966', ',', 'often', 'called', 'Nobel', 'Prize', 'computing', ',', 'includes', '$', '1', 'million', 'prize', ',', 'three', 'scientists', 'share', '.']
#
# Stemmed Sentence:
#  ['on', 'wednesday', ',', 'associ', 'comput', 'machineri', ',', 'world’', 'largest', 'societi', 'comput', 'profession', ',', 'announc', 'hinton', ',', 'lecun', 'bengio', 'year’', 'ture', 'award', 'work', 'neural', 'networks.', 'the', 'ture', 'award', ',', 'introduc', '1966', ',', 'often', 'call', 'nobel', 'prize', 'comput', ',', 'includ', '$', '1', 'million', 'prize', ',', 'three', 'scientist', 'share', '.']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rtang\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem.wordnet import WordNetLemmatizer

lem = WordNetLemmatizer()

lemm_words = []

for i in range(len(filtered_words)):
    lemm_words.append(lem.lemmatize(filtered_words[i]))

print(lemm_words)
# Out:
# ['On', 'Wednesday', ',', 'Association', 'Computing', 'Machinery', ',', 'world’s', 'largest', 'society', 'computing', 'professional', ',', 'announced', 'Hinton', ',', 'LeCun', 'Bengio', 'year’s', 'Turing', 'Award', 'work', 'neural', 'networks.', 'The', 'Turing', 'Award', ',', 'introduced', '1966', ',', 'often', 'called', 'Nobel', 'Prize', 'computing', ',', 'includes', '$', '1', 'million', 'prize', ',', 'three', 'scientist', 'share', '.']

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\rtang\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\rtang\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk import pos_tag

# %%
pos_tagged_words = pos_tag(word_tk)
print(pos_tagged_words)
# Out:
# [('On', 'IN'), ('Wednesday', 'NNP'), (',', ','), ('the', 'DT'), ('Association', 'NNP'), ('for', 'IN'), ('Computing', 'VBG'), ('Machinery', 'NNP'), (',', ','), ('the', 'DT'), ('world’s', 'NN'), ('largest', 'JJS'), ('society', 'NN'), ('of', 'IN'), ('computing', 'VBG'), ('professionals', 'NNS'), (',', ','), ('announced', 'VBD'), ('that', 'IN'), ('Hinton', 'NNP'), (',', ','), ('LeCun', 'NNP'), ('and', 'CC'), ('Bengio', 'NNP'), ('had', 'VBD'), ('won', 'VBN'), ('this', 'DT'), ('year’s', 'NN'), ('Turing', 'NNP'), ('Award', 'NNP'), ('for', 'IN'), ('their', 'PRP$'), ('work', 'NN'), ('on', 'IN'), ('neural', 'JJ'), ('networks.', 'IN'), ('The', 'DT'), ('Turing', 'NNP'), ('Award', 'NNP'), (',', ','), ('which', 'WDT'), ('was', 'VBD'), ('introduced', 'VBN'), ('in', 'IN'), ('1966', 'CD'), (',', ','), ('is', 'VBZ'), ('often', 'RB'), ('called', 'VBN'), ('the', 'DT'), ('Nobel', 'NNP'), ('Prize', 'NNP'), ('of', 'IN'), ('computing', 'NN'), (',', ','), ('and', 'CC'), ('it', 'PRP'), ('includes', 'VBZ'), ('a', 'DT'), ('$', '$'), ('1', 'CD'), ('million', 'CD'), ('prize', 'NN'), (',', ','), ('which', 'WDT'), ('the', 'DT'), ('three', 'CD'), ('scientists', 'NNS'), ('will', 'MD'), ('share', 'NN'), ('.', '.')]

# %%
from nltk.probability import FreqDist
fd = FreqDist(word_tk)
print(fd)
# Out:
# <FreqDist with 54 samples and 71 outcomes>

# %%
import matplotlib.pyplot as plt
fd.plot(30,cumulative=False)
plt.show()

# %%
fd_alpha = FreqDist(text)
print(fd_alpha)
fd_alpha.plot(30, cumulative=False)
# Out:
# <FreqDist with 41 samples and 387 outcomes>
# <Axes: xlabel='Samples', ylabel='Counts'>
