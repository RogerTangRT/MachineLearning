# %% [markdown]
# # Simple linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn 

from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10,8

# %%
rooms = 2*np.random.randn(100,1)+3
rooms[0:10]
# Out:
# array([[1.62634812],
#        [3.8732109 ],
#        [4.78420547],
#        [2.13106051],
#        [7.22205859],
#        [1.69006198],
#        [4.43502429],
#        [1.46764553],
#        [5.63190963],
#        [4.08584604]])

# %%
price = 265 + 6*rooms + abs(np.random.randn(100,1))
price[0:10]
# Out:
# array([[275.75008817],
#        [288.24074367],
#        [295.2043503 ],
#        [278.18514245],
#        [308.80706074],
#        [275.33216541],
#        [292.1474025 ],
#        [273.89982703],
#        [299.37466525],
#        [290.1340808 ]])

# %%
plt.plot(rooms,price,'r^')
plt.xlabel('# of Rooms 2024 Average')
plt.ylabel('2024 Average Home Price, $1000 USD')
plt.show()

# %%
X = rooms
y = price

LinReg = LinearRegression()
LinReg.fit(X,y)
print(LinReg.intercept_,LinReg.coef_)
# Out:
# [265.60893856] [[6.03270469]]

# %% [markdown]
# *Simple Algebra*
# - y = mx + b
# - b = intercept = 265.60
#
# *Estimated Coefficients*
# - LinReg.coef_ = [6.03] Estimated coefficients for the terms in the linear regression problem.

# %%
print(LinReg.score(X,y))
# Out:
# 0.9979403544944824
