# %% [markdown]
# # Visualização de Dados

# %%
# Instalando bibliotecas de visualização de dados
# !pip install --upgrade pip
# !pip install pandas
# !pip install Matplotlib
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.2 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 25.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 20.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------- ----- 6.0/7.1 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 27.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %%
# Importando bibliotecas
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame

# %% [markdown]
# ## Criando Dataset

# %%
data = {'names':['steve','john','richard','sarah','randy','micheal','julie'],
        'age':[20,22,20,21,24,23,22],
        'gender':['Male','Male','Male','Female','Male','Male','Female'],
        'rank':[2,1,4,5,3,7,6]}
df = DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0    steve   20    Male     2
# 1     john   22    Male     1
# 2  richard   20    Male     4
# 3    sarah   21  Female     5
# 4    randy   24    Male     3
# 5  micheal   23    Male     7
# 6    julie   22  Female     6

# %% [markdown]
# ## Grafico de Barras do Matplotlib

# %%
# Criando grafico de Barras com coluna do nome
plt.bar(df['names'],df['age'])
# Label do X
plt.xlabel('Names')
# Label do Y
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %% [markdown]
# ## Grafico de Barras do Seaborn

# %%
plot = sns.barplot(data=df, x='names',y='age')
plot.set_title("Comparing Ages")
# Out:
# Text(0.5, 1.0, 'Comparing Ages')

# %% [markdown]
# ## Gráfico de Linha Mathplotlib

# %%
plt.plot(df['names'], df['age'])
# Label do X
plt.xlabel('Names')
# Label do Y
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %% [markdown]
# ## Gráfico de Linha Seaborn

# %%
plot = sns.lineplot(data=df,x='names',y='age')
plt.show()

# %% [markdown]
# ## Gráfico de Pizza Matplotlib

# %%
plt.pie(df['age'],labels=df['names'])
plt.title("Age Comparison")
plt.show()

# %% [markdown]
# ## Grafico de Pizza Seaborn

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'],labels=df['names'],colors=colors)
plt.show()
