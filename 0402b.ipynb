# %% [markdown]
# # Creating a line Chart from a list objects

# %%
# Importando as bibliotecas
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ## Plot a line chart in matplotlib

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x,y)

# %%
# Preparando os dados
# Lê do arquivo csv
address = r'G:\Meu Drive\Cursos\Python\MachineLearning\cars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','MilesPerGalon','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']
cars.head()
# Out:
#            car_names  MilesPerGalon  cyl   disp   hp  drat     wt   qsec  vs  \
# 0          Mazda RX4           21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      Mazda RX4 Wag           21.0    6  160.0  110  3.90  2.875  17.02   0
# 2         Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1
# 3     Hornet 4 Drive           21.4    6  258.0  110  3.08  3.215  19.44   1
# 4  Hornet Sportabout           18.7    8  360.0  175  3.15  3.440  17.02   0
#
#    am  gear  carb
# 0   1     4     4
# 1   1     4     4
# 2   1     4     1
# 3   0     3     1
# 4   0     3     2

# %%
mpg = cars['MilesPerGalon']
mpg.plot()
# Out:
# <Axes: >

# %%
df = cars[['cyl','wt','MilesPerGalon']]
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Creating bar chats

# %% [markdown]
# ## Creating a bar chart from a list

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ## Creating bar charts from Pandas object

# %%
mpg.plot(kind='bar')
# Out:
# <Axes: >

# %%
mpg.plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ## Creating a pie chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ## Saving a plot as image file

# %%
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show()
