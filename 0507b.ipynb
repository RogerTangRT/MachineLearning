# %% [markdown]
# # Multivariante analysis for outlier detection

# %%
# Imports
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize']= 5,4

# %% [markdown]
# ## Visually inspacting boxplots

# %% [markdown]
# [Descrição dos Campos iris.data](Iris.md)

# %%
address = r'.\iris.data.csv'
df = pd.read_csv(filepath_or_buffer=address, header=None, sep=',')
df.columns = ['Sepal Length','Sepal Width','Petal Length','Petal Width', 'Species']
df.head(15)
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
# x -> matriz com as 4 primeiras colunas
x = df.iloc[:,0:4].values
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
# y -> vetor com a 5ª coluna
y = df.iloc[:,4].values
y
# Out:
# <StringArray>
# [   'Setosa',    'Setosa',    'Setosa',    'Setosa',    'Setosa',    'Setosa',
#     'Setosa',    'Setosa',    'Setosa',    'Setosa',
#  ...
#  'Virginica', 'Virginica', 'Virginica', 'Virginica', 'Virginica', 'Virginica',
#  'Virginica', 'Virginica', 'Virginica', 'Virginica']
# Length: 150, dtype: str

# %%
# Mostra as 5 primeiras linhas do DataFrame
df[:5]
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.boxplot(x='Species', y = 'Sepal Length', data=df, hue='Species', palette='hls', legend=False)
# Out:
# <Axes: xlabel='Species', ylabel='Sepal Length'>

# %% [markdown]
# ## Looking at the scatterplot matrix

# %%
sns.pairplot(df,hue='Species',palette='hls')

# %% [markdown]
# ## Applying Tukey outlier labeling

# %%
pd.options.display.float_format = '{:.1f}'.format

X_df = pd.DataFrame(x)
print(X_df.describe())
# Out:
#           0     1     2     3
# count 150.0 150.0 150.0 150.0
# mean    5.8   3.1   3.8   1.2
# std     0.8   0.4   1.8   0.8
# min     4.3   2.0   1.0   0.1
# 25%     5.1   2.8   1.6   0.3
# 50%     5.8   3.0   4.3   1.3
# 75%     6.4   3.3   5.1   1.8
# max     7.9   4.4   6.9   2.5
